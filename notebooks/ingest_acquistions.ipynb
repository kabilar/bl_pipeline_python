# %% [markdown]
# # Ingest acquisitions session path on bl_new_acquisition.Acquisitions

# %%
from scripts.conf_file_finding import try_find_conf_file
try_find_conf_file()
# Out:
# Local configuration file found !!, no need to run the configuration (unless configuration has changed)

# %% [markdown]
# ## Connection to DB

# %%
import datajoint as dj
import pandas as pd
import utility.path_utility as pu
import os
import pathlib
import numpy as np
import bl_pipeline.acquisition as acq

new_lab = dj.create_virtual_module('new_lab', 'bl_new_lab')
new_subject = dj.create_virtual_module('new_subject', 'bl_new_subject')
new_acquisition = dj.create_virtual_module('new_acquisition', 'bl_new_acquisition')

#bdata          = dj.create_virtual_module('bdata', 'bl_bdata')
#shadow_acquisition = dj.create_virtual_module('shadow_acquisition', 'bl_shadow_acquisition')
#new_acquisition = dj.create_virtual_module('new_acquisition', 'bl_new_acquisition')
#new_lab = dj.create_virtual_module('new_lav', 'bl_new_lab')
#ratinfo        = dj.create_virtual_module('ratinfo', 'bl_ratinfo')
# Out:
# Connecting alvaros@datajoint01.pni.princeton.edu:3306

# %% [markdown]
# ### 1. Get all directories with raw acquisition from root_ephys_directory

# %%
root_dir = pathlib.Path(dj.config['custom']['ephys_root_data_dir'][0])
posix_root_dir = pathlib.Path(root_dir).as_posix()

fields_t_acq  = pd.DataFrame.from_dict(acq.Acquisitions.heading.attributes, orient='index')
acquisitions_found = 0
acquisition_df = pd.DataFrame(columns=fields_t_acq.index.to_list()) 
acquisition_df = acquisition_df.drop(columns=['acquisition_id', 'user_id', 'acquisition_sessid'])

for root, dirs, files in os.walk(root_dir):
    for dirname in dirs:
        aux_dir = pathlib.Path(os.path.join(root, dirname))
        str_dir = str(aux_dir.as_posix())
        rel_dir = str_dir.replace(str(posix_root_dir), "")
        status_dir = pu.check_file_pattern_dir(str(aux_dir), pu.file_pattern_ephys_session['raw_np_files'], search_childs=False)
        
        if status_dir: 
            acquisitions_found += 1
            acquisition_df.loc[len(acquisition_df.index), 'acquisition_raw_rel_path'] = rel_dir
            
acquisition_df
# Out:
#      acquisition_rat acquisition_type  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
# ...              ...              ...
# 1043             NaN              NaN
# 1044             NaN              NaN
# 1045             NaN              NaN
# 1046             NaN              NaN
# 1047             NaN              NaN
#
#                                acquisition_raw_rel_path
# 0        /Adrian/A230/2019-07-04_g0/2019-07-04_g0_imec0
# 1        /Adrian/A230/2019-07-04_g0/2019-07-04_g0_imec1
# 2        /Adrian/A230/2019-07-04_g0/2019-07-04_g0_imec2
# 3        /Adrian/A230/2019-07-06_g0/2019-07-06_g0_imec0
# 4        /Adrian/A230/2019-07-06_g0/2019-07-06_g0_imec1
# ...                                                 ...
# 1043  /VGAT-ReaChR acute 2020_01_31/500um distance/V...
# 1044  /VGAT-ReaChR acute 2020_01_31/500um distance/V...
# 1045  /VGAT-ReaChR acute 2020_01_31/500um distance/V...
# 1046  /VGAT-ReaChR acute 2020_01_31/500um lateral 40...
# 1047  /VGAT-ReaChR acute 2020_01_31/500um lateral 40...
#
# [1048 rows x 3 columns]

# %%
copy_acquisition_df = acquisition_df.copy()

# %%
acquisition_df = copy_acquisition_df.copy()

# %% [markdown]
# ### 1a Get all directories with sorted results from clusterings_root_data_dir

# %%
sorted_dir = pathlib.Path(dj.config['custom']['ephys_root_data_dir'][1])
posix_sorted_dir = pathlib.Path(sorted_dir).as_posix()

fields_t_sort = pd.DataFrame.from_dict(acq.Sortings.heading.attributes, orient='index')
sorted_found = 0
sorted_df = pd.DataFrame(columns=fields_t_sort.index.to_list()) 
sorted_df = sorted_df.drop(columns=['acquisition_id', 'sorting_id'])


for root, dirs, files in os.walk(sorted_dir):
    for dirname in dirs:
        aux_dir = pathlib.Path(os.path.join(root, dirname))
        str_dir = str(aux_dir.as_posix())
        rel_dir = str_dir.replace(str(posix_sorted_dir), "") 
        status_dir_sorted = pu.check_file_pattern_dir(str(aux_dir), pu.file_pattern_ephys_session['sorted_np_files'], search_childs=False)
        
        if status_dir_sorted: 
            sorted_found += 1
            sorted_df.loc[len(sorted_df.index), 'acquisition_post_rel_path'] = rel_dir            
    #if acquisitions_found > 100:
        #break
        
        
sorted_df
# Out:
#                              acquisition_post_rel_path
# 0          /Adrian/A230/2019-07-04/2019-07-04_g0_imec0
# 1          /Adrian/A230/2019-07-04/2019-07-04_g0_imec1
# 2          /Adrian/A230/2019-07-04/2019-07-04_g0_imec2
# 3    /Adrian/A230/2019-07-04 (bank 0)/2019-07-04_g0...
# 4    /Adrian/A230/2019-07-04 (bank 0)/2019-07-04_g0...
# ..                                                 ...
# 747  /Thomas/T304/T304_2020_10_04_2.8mm_ML/spikesor...
# 748  /Thomas/T305/T305_2020_10_17/spikesort_2020_10...
# 749  /Thomas/T305/T305_2020_10_17b/spikesort_2020_1...
# 750  /Thomas/T305/T305_2020_10_17c/spikesort_2020_1...
# 751  /Thomas/T305/T305_2020_12_05b/spikesort_2020_1...
#
# [752 rows x 1 columns]

# %% [markdown]
# ### 2. Infer subject and rat from path

# %%
acquisition_df['acquisition_type'] = 'ephys'
acquisition_df['experimenter'] = acquisition_df['acquisition_raw_rel_path'].str.split('/').str[1]
acquisition_df['acquisition_rat'] = acquisition_df['acquisition_raw_rel_path'].str.split('/').str[2]

# %% [markdown]
# ### 3. Get experimenter user_id and merge with corresponding acquisition

# %%
contact_df = pd.DataFrame(new_lab.Contacts.fetch('user_id', 'experimenter', as_dict=True))
acquisition_df_nouser = acquisition_df.copy()
acquisition_df = acquisition_df.merge(contact_df, on='experimenter', how='inner')
acquisition_df_nouser = acquisition_df_nouser.merge(contact_df, on='experimenter', how='left')
acquisition_df_nouser = acquisition_df_nouser.loc[acquisition_df_nouser['user_id'].isnull(), :]
acquisition_df_nouser
# Out:
#                acquisition_rat acquisition_type  \
# 1035           1500um distance            ephys
# 1036           1500um distance            ephys
# 1037           1500um distance            ephys
# 1038           1500um distance            ephys
# 1039              1mm distance            ephys
# 1040            500um distance            ephys
# 1041            500um distance            ephys
# 1042            500um distance            ephys
# 1043            500um distance            ephys
# 1044            500um distance            ephys
# 1045            500um distance            ephys
# 1046  500um lateral 400um core            ephys
# 1047  500um lateral 400um core            ephys
#
#                                acquisition_raw_rel_path  \
# 1035  /VGAT-ReaChR acute 2020_01_31/1500um distance/...
# 1036  /VGAT-ReaChR acute 2020_01_31/1500um distance/...
# 1037  /VGAT-ReaChR acute 2020_01_31/1500um distance/...
# 1038  /VGAT-ReaChR acute 2020_01_31/1500um distance/...
# 1039  /VGAT-ReaChR acute 2020_01_31/1mm distance/VGA...
# 1040  /VGAT-ReaChR acute 2020_01_31/500um distance/V...
# 1041  /VGAT-ReaChR acute 2020_01_31/500um distance/V...
# 1042  /VGAT-ReaChR acute 2020_01_31/500um distance/V...
# 1043  /VGAT-ReaChR acute 2020_01_31/500um distance/V...
# 1044  /VGAT-ReaChR acute 2020_01_31/500um distance/V...
# 1045  /VGAT-ReaChR acute 2020_01_31/500um distance/V...
# 1046  /VGAT-ReaChR acute 2020_01_31/500um lateral 40...
# 1047  /VGAT-ReaChR acute 2020_01_31/500um lateral 40...
#
#                       experimenter user_id
# 1035  VGAT-ReaChR acute 2020_01_31     NaN
# 1036  VGAT-ReaChR acute 2020_01_31     NaN
# 1037  VGAT-ReaChR acute 2020_01_31     NaN
# 1038  VGAT-ReaChR acute 2020_01_31     NaN
# 1039  VGAT-ReaChR acute 2020_01_31     NaN
# 1040  VGAT-ReaChR acute 2020_01_31     NaN
# 1041  VGAT-ReaChR acute 2020_01_31     NaN
# 1042  VGAT-ReaChR acute 2020_01_31     NaN
# 1043  VGAT-ReaChR acute 2020_01_31     NaN
# 1044  VGAT-ReaChR acute 2020_01_31     NaN
# 1045  VGAT-ReaChR acute 2020_01_31     NaN
# 1046  VGAT-ReaChR acute 2020_01_31     NaN
# 1047  VGAT-ReaChR acute 2020_01_31     NaN

# %% [markdown]
# ### 4. Check corresponding ratname and filter non matching

# %%
subject_df = pd.DataFrame(new_subject.Rats.fetch('ratname', as_dict=True))
acquisition_df_norat = acquisition_df.copy()
acquisition_df = acquisition_df.merge(subject_df, left_on='acquisition_rat', right_on='ratname', how='inner')
acquisition_dfnorat = acquisition_df_norat.merge(subject_df, left_on='acquisition_rat', right_on='ratname', how='left')
acquisition_dfnorat = acquisition_dfnorat.loc[acquisition_dfnorat['ratname'].isnull(), :]
acquisition_dfnorat
# Out:
#      acquisition_rat acquisition_type  \
# 281      Unimplanted            ephys
# 282      Unimplanted            ephys
# 283      Unimplanted            ephys
# 284      Unimplanted            ephys
# 285      Unimplanted            ephys
# ...              ...              ...
# 1030     Unimplanted            ephys
# 1031     Unimplanted            ephys
# 1032     Unimplanted            ephys
# 1033     Unimplanted            ephys
# 1034     Unimplanted            ephys
#
#                                acquisition_raw_rel_path experimenter  user_id  \
# 281   /Adrian/Unimplanted/trying to break a probe wi...       Adrian   abondy
# 282   /Adrian/Unimplanted/trying to break a probe wi...       Adrian   abondy
# 283   /Adrian/Unimplanted/trying to break a probe wi...       Adrian   abondy
# 284   /Adrian/Unimplanted/trying to break a probe wi...       Adrian   abondy
# 285   /Adrian/Unimplanted/trying to break a probe wi...       Adrian   abondy
# ...                                                 ...          ...      ...
# 1030  /Thomas/Unimplanted/gain_noise_18194819542_202...       Thomas  zhihaol
# 1031  /Thomas/Unimplanted/gain_noise_18194819542_202...       Thomas  zhihaol
# 1032  /Thomas/Unimplanted/gain_noise_18194819542_202...       Thomas  zhihaol
# 1033  /Thomas/Unimplanted/gain_noise_18194819542_202...       Thomas  zhihaol
# 1034  /Thomas/Unimplanted/gain_noise_18194819542_202...       Thomas  zhihaol
#
#      ratname
# 281      NaN
# 282      NaN
# 283      NaN
# 284      NaN
# 285      NaN
# ...      ...
# 1030     NaN
# 1031     NaN
# 1032     NaN
# 1033     NaN
# 1034     NaN
#
# [100 rows x 6 columns]

# %% [markdown]
# ### 5 Check corresponding session and add it

# %%
ephys_session_df = pd.DataFrame(new_acquisition.AcquisitionSessions.fetch('sessid', 'acquisition_raw_rel_path', as_dict=True))
ephys_session_df = ephys_session_df.rename(columns={'sessid':'acquisition_sessid'})
acquisition_df_nosession = acquisition_df.copy()
acquisition_df = acquisition_df.merge(ephys_session_df, on='acquisition_raw_rel_path', how='left')
#acquisition_df['acquisition_sessid'] = acquisition_df['acquisition_sessid'].astype('Int32')

acquisition_df_nosession = acquisition_df_nosession.merge(ephys_session_df, on='acquisition_raw_rel_path', how='left')
acquisition_df_nosession = acquisition_df_nosession.loc[acquisition_df_nosession['acquisition_sessid'].isnull(), :]
acquisition_df_nosession
# Out:
#     acquisition_rat acquisition_type  \
# 0              A230            ephys
# 1              A230            ephys
# 2              A230            ephys
# 3              A230            ephys
# 4              A230            ephys
# ..              ...              ...
# 930            T304            ephys
# 931            T305            ephys
# 932            T305            ephys
# 933            T305            ephys
# 934            T305            ephys
#
#                            acquisition_raw_rel_path experimenter  user_id  \
# 0    /Adrian/A230/2019-07-04_g0/2019-07-04_g0_imec0       Adrian   abondy
# 1    /Adrian/A230/2019-07-04_g0/2019-07-04_g0_imec1       Adrian   abondy
# 2    /Adrian/A230/2019-07-04_g0/2019-07-04_g0_imec2       Adrian   abondy
# 3    /Adrian/A230/2019-07-06_g0/2019-07-06_g0_imec0       Adrian   abondy
# 4    /Adrian/A230/2019-07-06_g0/2019-07-06_g0_imec1       Adrian   abondy
# ..                                              ...          ...      ...
# 930        /Thomas/T304/T304_2020_10_04_2.8mm_ML_g0       Thomas  zhihaol
# 931                /Thomas/T305/T305_2020_10_17b_g0       Thomas  zhihaol
# 932                /Thomas/T305/T305_2020_10_17c_g0       Thomas  zhihaol
# 933                 /Thomas/T305/T305_2020_10_17_g0       Thomas  zhihaol
# 934                /Thomas/T305/T305_2020_12_05b_g0       Thomas  zhihaol
#
#     ratname  acquisition_sessid
# 0      A230                 NaN
# 1      A230                 NaN
# 2      A230                 NaN
# 3      A230                 NaN
# 4      A230                 NaN
# ..      ...                 ...
# 930    T304                 NaN
# 931    T305                 NaN
# 932    T305                 NaN
# 933    T305                 NaN
# 934    T305                 NaN
#
# [648 rows x 7 columns]

# %% [markdown]
# ## 6 Insert all acquisitions found

# %%
acquisition_df = acquisition_df.drop(columns=['experimenter', 'ratname'])
#acq.Acquisitions.insert(acquisition_df, skip_duplicates=True)

# %%
acquisition_db_df = pd.DataFrame(acq.Acquisitions.fetch(as_dict=True))
acquisition_db_df
# Out:
#      acquisition_id  acquisition_sessid acquisition_rat  user_id  \
# 0                 1                 NaN            A230   abondy
# 1                 2                 NaN            A230   abondy
# 2                 3                 NaN            A230   abondy
# 3                 4                 NaN            A230   abondy
# 4                 5                 NaN            A230   abondy
# ..              ...                 ...             ...      ...
# 930             931                 NaN            T304  zhihaol
# 931             932                 NaN            T305  zhihaol
# 932             933                 NaN            T305  zhihaol
# 933             934                 NaN            T305  zhihaol
# 934             935                 NaN            T305  zhihaol
#
#     acquisition_type                        acquisition_raw_rel_path
# 0              ephys  /Adrian/A230/2019-07-04_g0/2019-07-04_g0_imec0
# 1              ephys  /Adrian/A230/2019-07-04_g0/2019-07-04_g0_imec1
# 2              ephys  /Adrian/A230/2019-07-04_g0/2019-07-04_g0_imec2
# 3              ephys  /Adrian/A230/2019-07-06_g0/2019-07-06_g0_imec0
# 4              ephys  /Adrian/A230/2019-07-06_g0/2019-07-06_g0_imec1
# ..               ...                                             ...
# 930            ephys        /Thomas/T304/T304_2020_10_04_2.8mm_ML_g0
# 931            ephys                /Thomas/T305/T305_2020_10_17b_g0
# 932            ephys                /Thomas/T305/T305_2020_10_17c_g0
# 933            ephys                 /Thomas/T305/T305_2020_10_17_g0
# 934            ephys                /Thomas/T305/T305_2020_12_05b_g0
#
# [935 rows x 6 columns]

# %% [markdown]
# ### 7 Merge acquisitions and sortings

# %%
acquisition_db_df = acquisition_db_df[['acquisition_raw_rel_path', 'acquisition_id']].copy()
sorted_df['acquisition_raw_rel_path'] = sorted_df.apply(lambda x: pu.get_parent_dir(x['acquisition_post_rel_path']), axis=1)

sorted_df2 = sorted_df.merge(acquisition_db_df, on='acquisition_raw_rel_path', how='inner')

sorted_df2
# Out:
#                              acquisition_post_rel_path  \
# 0    /Adrian/A230/A230_2019_07_15/2019-07-15_g0_ime...
# 1    /Adrian/A241/A241_2020_01_14/A241_2020_01_14_g...
# 2    /Adrian/A241/A241_2020_01_14/A241_2020_01_14_g...
# 3    /Adrian/A241/A241_2020_01_22/A241_2020_01_22_g...
# 4    /Adrian/A241/A241_2020_01_23/A241_2020_01_23_g...
# ..                                                 ...
# 240  /Thomas/T227/T227_2020_03_14_idle_bank0/spikes...
# 241  /Thomas/T227/T227_2020_03_14_idle_bank1/spikes...
# 242  /Thomas/T227/T227_2020_03_15_idle_bank0/spikes...
# 243  /Thomas/T227/T227_2020_03_15_idle_bank1/spikes...
# 244  /Thomas/T274/T274_2020_12_04_segment0to5324/sp...
#
#                              acquisition_raw_rel_path  acquisition_id
# 0    /Adrian/A230/A230_2019_07_15/2019-07-15_g0_imec0              19
# 1     /Adrian/A241/A241_2020_01_14/A241_2020_01_14_g0              78
# 2     /Adrian/A241/A241_2020_01_14/A241_2020_01_14_g0              78
# 3     /Adrian/A241/A241_2020_01_22/A241_2020_01_22_g0              79
# 4     /Adrian/A241/A241_2020_01_23/A241_2020_01_23_g0              80
# ..                                                ...             ...
# 240           /Thomas/T227/T227_2020_03_14_idle_bank0             784
# 241           /Thomas/T227/T227_2020_03_14_idle_bank1             785
# 242           /Thomas/T227/T227_2020_03_15_idle_bank0             786
# 243           /Thomas/T227/T227_2020_03_15_idle_bank1             787
# 244       /Thomas/T274/T274_2020_12_04_segment0to5324             917
#
# [245 rows x 3 columns]

# %%
sorted_df2 = sorted_df2.drop(columns=['acquisition_raw_rel_path'])
#acq.Sortings.insert(sorted_df2, skip_duplicates=True)

# %%
sortings_db_df = pd.DataFrame(acq.Sortings.fetch(as_dict=True))
sortings_db_df
# Out:
#      sorting_id  acquisition_id  \
# 0             1              19
# 1             2              78
# 2             3              78
# 3             4              79
# 4             5              80
# ..          ...             ...
# 465         466             931
# 466         467             934
# 467         468             932
# 468         469             933
# 469         470             935
#
#                              acquisition_post_rel_path
# 0    /Adrian/A230/A230_2019_07_15/2019-07-15_g0_ime...
# 1    /Adrian/A241/A241_2020_01_14/A241_2020_01_14_g...
# 2    /Adrian/A241/A241_2020_01_14/A241_2020_01_14_g...
# 3    /Adrian/A241/A241_2020_01_22/A241_2020_01_22_g...
# 4    /Adrian/A241/A241_2020_01_23/A241_2020_01_23_g...
# ..                                                 ...
# 465  /Thomas/T304/T304_2020_10_04_2.8mm_ML/spikesor...
# 466  /Thomas/T305/T305_2020_10_17/spikesort_2020_10...
# 467  /Thomas/T305/T305_2020_10_17b/spikesort_2020_1...
# 468  /Thomas/T305/T305_2020_10_17c/spikesort_2020_1...
# 469  /Thomas/T305/T305_2020_12_05b/spikesort_2020_1...
#
# [470 rows x 3 columns]

# %% [markdown]
# ### Account for g0 suffix

# %%
sorted_df4 = sorted_df.copy()
sorted_df4['acquisition_raw_rel_path'] = sorted_df4['acquisition_raw_rel_path'] + '_g0'
sorted_df4
# Out:
#                              acquisition_post_rel_path  \
# 0          /Adrian/A230/2019-07-04/2019-07-04_g0_imec0
# 1          /Adrian/A230/2019-07-04/2019-07-04_g0_imec1
# 2          /Adrian/A230/2019-07-04/2019-07-04_g0_imec2
# 3    /Adrian/A230/2019-07-04 (bank 0)/2019-07-04_g0...
# 4    /Adrian/A230/2019-07-04 (bank 0)/2019-07-04_g0...
# ..                                                 ...
# 747  /Thomas/T304/T304_2020_10_04_2.8mm_ML/spikesor...
# 748  /Thomas/T305/T305_2020_10_17/spikesort_2020_10...
# 749  /Thomas/T305/T305_2020_10_17b/spikesort_2020_1...
# 750  /Thomas/T305/T305_2020_10_17c/spikesort_2020_1...
# 751  /Thomas/T305/T305_2020_12_05b/spikesort_2020_1...
#
#                      acquisition_raw_rel_path
# 0                  /Adrian/A230/2019-07-04_g0
# 1                  /Adrian/A230/2019-07-04_g0
# 2                  /Adrian/A230/2019-07-04_g0
# 3         /Adrian/A230/2019-07-04 (bank 0)_g0
# 4         /Adrian/A230/2019-07-04 (bank 0)_g0
# ..                                        ...
# 747  /Thomas/T304/T304_2020_10_04_2.8mm_ML_g0
# 748           /Thomas/T305/T305_2020_10_17_g0
# 749          /Thomas/T305/T305_2020_10_17b_g0
# 750          /Thomas/T305/T305_2020_10_17c_g0
# 751          /Thomas/T305/T305_2020_12_05b_g0
#
# [752 rows x 2 columns]

# %%
sorted_df5 = sorted_df4.merge(acquisition_db_df, on='acquisition_raw_rel_path', how='inner')
sorted_df5
# Out:
#                              acquisition_post_rel_path  \
# 0    /Thomas/T181/T181_2019_11_11_bank0/spikesort_2...
# 1    /Thomas/T181/T181_2019_11_11_bank1/spikesort_2...
# 2    /Thomas/T219/T219_2019_11_17_bank0/spikesort_2...
# 3    /Thomas/T219/T219_2019_11_17_bank1/spikesort_2...
# 4    /Thomas/T219/T219_2019_11_18_bank0/spikesort_2...
# ..                                                 ...
# 220  /Thomas/T304/T304_2020_10_04_2.8mm_ML/spikesor...
# 221  /Thomas/T305/T305_2020_10_17/spikesort_2020_10...
# 222  /Thomas/T305/T305_2020_10_17b/spikesort_2020_1...
# 223  /Thomas/T305/T305_2020_10_17c/spikesort_2020_1...
# 224  /Thomas/T305/T305_2020_12_05b/spikesort_2020_1...
#
#                      acquisition_raw_rel_path  acquisition_id
# 0       /Thomas/T181/T181_2019_11_11_bank0_g0             573
# 1       /Thomas/T181/T181_2019_11_11_bank1_g0             574
# 2       /Thomas/T219/T219_2019_11_17_bank0_g0             656
# 3       /Thomas/T219/T219_2019_11_17_bank1_g0             657
# 4       /Thomas/T219/T219_2019_11_18_bank0_g0             658
# ..                                        ...             ...
# 220  /Thomas/T304/T304_2020_10_04_2.8mm_ML_g0             931
# 221           /Thomas/T305/T305_2020_10_17_g0             934
# 222          /Thomas/T305/T305_2020_10_17b_g0             932
# 223          /Thomas/T305/T305_2020_10_17c_g0             933
# 224          /Thomas/T305/T305_2020_12_05b_g0             935
#
# [225 rows x 3 columns]

# %%
sorted_df5 = sorted_df5.drop(columns=['acquisition_raw_rel_path'])
#acq.Sortings.insert(sorted_df5, skip_duplicates=True)
